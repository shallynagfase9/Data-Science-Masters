# %% [markdown]
# <a href="https://colab.research.google.com/github/shallynagfase9/Python-for-Data-Science/blob/main/Bokeh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bokeh

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')

p = figure(title = "test flower")
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.circle(flowers["petal_length"],flowers["petal_width"])
show(p)
# Out:
#   <div id="b1706306-28a1-4ca8-a09c-5b481d18fc30" data-root-id="p1147" style="display: contents;"></div>

# %%
output_file('test.html')

p = figure(title = "test flower")
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.line(flowers["petal_length"],flowers["petal_width"])
show(p)
# Out:
#   <div id="f9838a35-4d90-4b77-bde1-5ca948cf2052" data-root-id="p1194" style="display: contents;"></div>

# %%
x = [1,2,3,4,5]
y = [4,5,6,1,2]
output_file("line.html")
p = figure(title="line graph")
p.line(x,y)
show(p)
# Out:
#   <div id="a446b310-6617-4884-aa79-3e46c30f5585" data-root-id="p1284" style="display: contents;"></div>

# %%
x = [1,2,3,4,5]
y = [4,5,6,1,2]
output_file("line.html")
p = figure(title="line graph")
p.scatter(x,y)
show(p)
# Out:
#   <div id="c91288ab-34b2-44fe-8deb-c03691e423f5" data-root-id="p1327" style="display: contents;"></div>

# %%
x = [1,2,3,4,5]
y = [4,5,6,1,2]
output_file("line.html")
p = figure(title="line graph")
p.scatter(x,y, size = 20,fill_color = "red", legend_label="This is my data points")
show(p)
# Out:
#   <div id="d75ced1d-bcbf-4f0a-aa50-683a082b4c60" data-root-id="p1450" style="display: contents;"></div>
