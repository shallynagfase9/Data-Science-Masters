# %% [markdown]
# <a href="https://colab.research.google.com/github/shallynagfase9/Data-Science-Masters/blob/main/label_%26_ordinal_encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
########### Label Encoding ##############
# Assigning labels to data point alphabetically
import pandas as pd

df = pd.DataFrame(
    {
        'color':["red","green","blue","green","red","blue"]
    }
)
df
# Out:
#    color
# 0    red
# 1  green
# 2   blue
# 3  green
# 4    red
# 5   blue

# %%
df.head()
# Out:
#    color
# 0    red
# 1  green
# 2   blue
# 3  green
# 4    red

# %%
from sklearn.preprocessing import LabelEncoder
lbl_encoder = LabelEncoder()

# %%
lbl_encoder.fit_transform(df["color"])
# Out:
# array([2, 1, 0, 1, 2, 0])

# %%
lbl_encoder.transform([["blue"]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# array([0])

# %%
lbl_encoder.transform([["green"]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# array([1])

# %%
########### Ordinal Encoding ##############
# Assigning ranks
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.DataFrame(
    {
        "size":["small","medium","large","medium","large","small"]
    }
)

df
# Out:
#      size
# 0   small
# 1  medium
# 2   large
# 3  medium
# 4   large
# 5   small

# %%
encoder = OrdinalEncoder(categories=[["small","medium","large"]])
encoder.fit_transform(df[["size"]])
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [0.]])

# %%
encoder.transform([["medium"]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
# array([[1.]])
